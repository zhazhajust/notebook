# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from matplotlib import pyplot as plt

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
ax.get_proj = lambda: np.dot(Axes3D.get_proj(ax), np.diag([3, 1, 1, 1]))
im=ax.scatter(a[:,1], a[:,2], a[:,3],s=1,c=a[:,0],cmap=plt.cm.rainbow)
cbar=plt.colorbar(im, pad=0.01)
fig.savefig('3d.png',dpi=400)
def rotate(angle): 
    ax.view_init(azim=angle) 
    rot_animation = animation.FuncAnimation(fig, rotate, frames=np.arange(0,362,2),interval=

# %%
a=np.loadtxt('a.txt')

# %%
a[]
# Out:
# array([ 4.0077027e+02,  9.0845472e-05,  3.7684325e-06, -7.7339217e-07])

# %%
a.shape
# Out:
# (576107, 4)

# %%
import sdf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-96bc9d1984ed> in <module>
# ----> 1 import sdf
#
# ImportError: dlopen(/Users/mac/.local/lib/python3.7/site-packages/sdf.cpython-37m-darwin.so, 2): Symbol not found: _sdf_delete_hash_block
#   Referenced from: /Users/mac/.local/lib/python3.7/site-packages/sdf.cpython-37m-darwin.so
#   Expected in: flat namespace
#  in /Users/mac/.local/lib/python3.7/site-packages/sdf.cpython-37m-darwin.so

# %%
import sdf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-96bc9d1984ed> in <module>
# ----> 1 import sdf
#
# ImportError: dlopen(/Users/mac/.local/lib/python3.7/site-packages/sdf.cpython-37m-darwin.so, 2): Symbol not found: _sdf_delete_hash_block
#   Referenced from: /Users/mac/.local/lib/python3.7/site-packages/sdf.cpython-37m-darwin.so
#   Expected in: flat namespace
#  in /Users/mac/.local/lib/python3.7/site-packages/sdf.cpython-37m-darwin.so
