# %%
import matplotlib.pyplot as plt
import math
import numpy as np
pi=3.1415926
length_x = 20e-6
length_y = 20e-6
X=np.linspace(0,1e-6,1000)
Y=np.linspace(0,1e-6,1000)
x,y=np.meshgrid(X,Y)
#a=(np.sin(2.0*pi*x/0.2e-6))*(np.sin(2.0*pi*y/0.2e-6))
move_sin = 0.6
a=1/(1-move_sin)*(((np.abs(np.sin(2*pi*x/0.4e-6)))*(np.abs(np.sin(2*pi*y/0.4e-6))))-move_sin)
fig,ax=plt.subplots()
im=ax.pcolormesh(x,y,a)
fig.colorbar(im,ax=ax)
fig2,ax2=plt.subplots()
a2=a[0].max()-a[0]
ax2.plot(a[100])
#ax.set_ylim([0,1])
#ax2.plot(a2)
#ax2.plot(np.sin(2.0*pi*x/length_x*10)[0])
plt.show()
